# %%
# %ls
# Out:
#  驱动器 F 中的卷是 工作
#  卷的序列号是 6C99-90C9
#
#  F:\PycharmProjects\tensorflow_study\src 的目录
#
# 2018/11/14  11:06    <DIR>          .
# 2018/11/14  11:06    <DIR>          ..
# 2018/11/14  11:06    <DIR>          .ipynb_checkpoints
# 2018/11/13  16:43             1,155 study1_nihe.py
# 2018/11/13  16:37               441 study2_session_control.py
# 2018/11/13  17:16               927 study3_variable.py
# 2018/11/13  17:24               507 study4_placeholder.py
# 2018/11/13  17:35               572 study5_add_layer.py
# 2018/11/14  10:32             2,293 study6_build_nn.py
# 2018/11/14  11:05            17,734 Untitled.ipynb
# 2018/11/14  11:06                72 Untitled1.ipynb
#                8 个文件         23,701 字节
#                3 个目录 83,723,980,800 可用字节

# %%
# %run study6_build_nn.py
# Out:
# 0.05640612
# name 'lines' is not defined
# 0.0074620564
# 0.006333693
# 0.005928329
# 0.0056737135
# 0.005440044
# 0.005210024
# 0.0050100735
# 0.004748639
# 0.0044604936
# 0.0041921344
# 0.0039765127
# 0.0037826125
# 0.0036251664
# 0.0035008034
# 0.0034016455
# 0.0033124662
# 0.0032447767
# 0.003207817
# 0.003175672
